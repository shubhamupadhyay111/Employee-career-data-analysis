# %% [markdown]
# #**EMPLOYEE CAREER SURVEY DATASET ANALYSIS**

# %% [markdown]
# #OBJECTIVE
# 1. What is the country of the employee?
# 2. What are the factors influencing the career aspirations of Genz?
# 3. How many want to pursue higher education outside india with their investment?
# 4. How likely Genz is to work for one company for three years or more?
# 5. What is the preferred working environment of Genz?

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("/content/drive/MyDrive/Mini project/Employee career analysis/Employee career analysis.csv")

# %%
df.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %% [markdown]
# #1. What is the country of the employees?

# %%
question1 = df["Your Current Country."].value_counts()
question1
# Out:
# Your Current Country.
# India                       231
# Germany                       2
# United Arab Emirates          1
# United States of America      1
# Name: count, dtype: int64

# %%
label = question1.index
counts = question1.values
colors = ['orange','lightgreen']
fig = go.Figure(data= [go.Pie(labels=label, values = counts)])
fig.update_layout(title_text = "current country")
fig.update_traces(hoverinfo = 'label+value', textinfo = 'percent', textfont_size = 20,
                  marker = dict(colors = colors, line = dict(color = 'grey',width =1.9)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #2. What are the factors influencing the career aspirations of Genz?

# %%
df.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
question2 = df['Which of the below factors influence the most about your career aspirations ?'].value_counts()
question2
# Out:
# Which of the below factors influence the most about your career aspirations ?
# My Parents                                       79
# People who have changed the world for better     57
# People from my circle, but not family members    39
# Influencers who had successful careers           37
# Social Media like LinkedIn                       23
# Name: count, dtype: int64

# %%
label = question2.index
counts = question2.values
colors = ['lightred','orange','yellow','lightgreen','lightblue']
fig = go.Figure(data = [go.Pie(labels = label, values = counts)])
fig.update_layout(title_text='Factors influencing career aspirations of the employees')
fig.update_traces(hoverinfo = 'label+value', textinfo='percent',textfont_size = 15,
                  marker = dict(colors = colors, line = dict(color = 'grey', width = 1.7)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #3. How many want to pursue higher education outside india with their investment?

# %%
df.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
question3 = df['Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.'].value_counts()
question3
# Out:
# Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.
# Yes, I will earn and do that                                    110
# No I would not be pursuing Higher Education outside of India     65
# No, But if someone could bare the cost I will                    60
# Name: count, dtype: int64

# %%
label = question3.index
counts = question3.values
fig = go.Figure(data = [go.Pie(labels = label, values = counts)])
fig.update_layout(title_text = 'How many employees leave india for their betterment')
fig.update_traces(hoverinfo = 'label+value', textinfo = 'percent', textfont_size = 20,
                  marker = dict(line = dict(color = 'grey',width=1.5)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #4. How likely Genz is to work for one company for three years or more?

# %%
df.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
question4 = df['How likely is that you will work for one employer for 3 years or more ?'].value_counts()
question4
# Out:
# How likely is that you will work for one employer for 3 years or more ?
# This will be hard to do, but if it is the right company I would try    139
# Will work for 3 years or more                                           79
# No way, 3 years with one employer is crazy                              17
# Name: count, dtype: int64

# %%
label = question4.index
counts = question4.values
colors = ['yellow','orange','green']
fig = go.Figure(data = [go.Pie(labels = label, values = counts)])
fig.update_layout(title_text = 'Will employees work for the company 3 or more than 3 years')
fig.update_traces(hoverinfo = 'label+value', textinfo = 'percent', textfont_size = 17,
                  marker =dict(colors = colors, line = dict(color = 'grey',width = 1.5)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #5.  What is the preferred working environment of Genz?

# %%
df.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
question5 = df['What is the most preferred working environment for you.'].value_counts()
question5
# Out:
# What is the most preferred working environment for you.
# Fully Remote with Options to travel as and when needed                 60
# Hybrid Working Environment with less than 15 days a month at office    57
# Every Day Office Environment                                           50
# Hybrid Working Environment with less than 10 days a month at office    31
# Hybrid Working Environment with less than 3 days a month at office     26
# Fully Remote with No option to visit offices                           11
# Name: count, dtype: int64

# %%
label = question5.index
counts = question5.values
colors = ['yellow','orange','green']
fig = go.Figure(data = [go.Pie(labels = label, values = counts)])
fig.update_layout(title_text = 'Will employees work for the company 3 or more than 3 years')
fig.update_traces(hoverinfo = 'label+value', textinfo = 'percent', textfont_size = 17,
                  marker =dict(colors = colors, line = dict(color = 'grey',width = 1.5)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
